# %% [markdown]
# <a href="https://colab.research.google.com/github/joyel10/data-visualization/blob/main/data_visualisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
iris=sns.load_dataset ("iris")

# %%
sns.lineplot(data=iris,x="sepal_length",y="sepal_width",hue="species")
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.regplot(data=iris,x="sepal_length",y="sepal_width",)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# heatmap

# %%
corr= iris.corr()
# Out:
# <ipython-input-49-c5eecd410b1f>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr= iris.corr()

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
sns.boxplot(data=iris)
# Out:
# <Axes: >

# %% [markdown]
# histogram

# %%
import numpy as np

# %%
x = np.random.randn(1000)
plt.hist(x,bins=50)
# Out:
# (array([ 4.,  1.,  0.,  0.,  2.,  1.,  4.,  7.,  7.,  5., 14., 11., 16.,
#         16., 25., 17., 28., 38., 30., 36., 27., 37., 39., 49., 42., 61.,
#         50., 50., 43., 50., 42., 35., 38., 30., 26., 27., 21., 12., 13.,
#         12.,  8.,  4.,  7.,  2.,  4.,  1.,  2.,  1.,  4.,  1.]),
#  array([-3.01913157, -2.90022752, -2.78132347, -2.66241942, -2.54351537,
#         -2.42461131, -2.30570726, -2.18680321, -2.06789916, -1.94899511,
#         -1.83009106, -1.71118701, -1.59228296, -1.47337891, -1.35447485,
#         -1.2355708 , -1.11666675, -0.9977627 , -0.87885865, -0.7599546 ,
#         -0.64105055, -0.5221465 , -0.40324244, -0.28433839, -0.16543434,
#         -0.04653029,  0.07237376,  0.19127781,  0.31018186,  0.42908591,
#          0.54798997,  0.66689402,  0.78579807,  0.90470212,  1.02360617,
#          1.14251022,  1.26141427,  1.38031832,  1.49922237,  1.61812643,
#          1.73703048,  1.85593453,  1.97483858,  2.09374263,  2.21264668,
# ...

# %%
plt.imshow(corr)
